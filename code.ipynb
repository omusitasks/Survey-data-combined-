# %%
import pandas as pd

# %%
# load data googleplaystore.csv dataset
data = pd.read_csv('Survey-data-combined .csv')   
data.head()
# Out:
#         age  gender length of residence family members Experience with Fire  \
# 0  Under 18    Male      Within 5 years   Living alone                 have
# 1     18-30  Female           5-10years     1-2 pieces                   no
# 2     31-50    Male   More than 10years     3-5 pieces                 have
# 3     51-70  Female      Within 5 years    5 and above                   no
# 4   Over 70    Male           5-10years   Living alone                 have
#
#                   Source of fire  opinion  IoT Installation  \
# 0  The wire is aging and exposed                        NaN
# 1            Debris accumulation                        NaN
# 2                  Cooking stove                        NaN
# 3                  Other factors                        NaN
# 4  The wire is aging and exposed                        NaN
#
#                        opinion on potential positive  \
# 0                          Provide timely fire alarm
# ...
